# %% [markdown]
# Ingest The Data

# %%
import requests
import json
# Out:
# StatementMeta(, 5119d43d-a021-41da-8300-8bb1ce214501, 4, Finished, Available, Finished)

# %%
# API  Url with start and end dates provided by Data Factory. formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
# Out:
# StatementMeta(, 5119d43d-a021-41da-8300-8bb1ce214501, 9, Finished, Available, Finished)

# %%
url
# Out:
# StatementMeta(, 5119d43d-a021-41da-8300-8bb1ce214501, 10, Finished, Available, Finished)
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-11-12&endtime=2025-11-18'

# %%
try:
    #Make the GET reuest to fetch data
    response = requests.get(url)

    # check if the request was successful
    response.raise_for_status() # Raise HttP error for bad responses (4xx or 5xx)
    data = response.json().get('features',[])

    if not data:
        print("no data retuned for the specified date range.")
    else:
        #specify the flie name (and path if needed)
        file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json' 

        # Save the json data
        with open(file_path,'w') as file:
            json.dump(data,file,indent=4)
        print(f"Data Successfuly Saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error  fetching data from API: {e}")
# Out:
# StatementMeta(, 5119d43d-a021-41da-8300-8bb1ce214501, 15, Finished, Available, Finished)
# Data Successfuly Saved to /lakehouse/default/Files/2025-11-12_earthquake_data.json

# %%
ls
# Out:
# StatementMeta(, 5119d43d-a021-41da-8300-8bb1ce214501, 16, Finished, Available, Finished)
# builtin@                                default_container_executor.sh*  sparkr@
# container_tokens                        launch_container.sh*            tmp/
# default_container_executor_session.sh*  __spark_conf__@
